# %% [markdown]
# # Segmenting ROI and RONI in CT scan
# ### Author- Anupreet Singh(UMBC Campus ID-UK43298)

# %%
## Setting up dependecies in the environment 
# %pip install opencv-python matplotlib 

# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# !pip install bchlib
# !pip install bitarray
# !pip install scikit-image

import cv2
import numpy as np
import matplotlib.pyplot as plt

import os
import hashlib
import bchlib
import binascii
from bitarray import bitarray
from skimage.metrics import structural_similarity
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from opencv-python) (2.2.4)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (2.2.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: bchlib in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: bitarray in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (3.3.1)
# Requirement already satisfied: scikit-image in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (2.2.4)
# Requirement already satisfied: scipy>=1.11.4 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/envs/ROI/lib/python3.10/site-packages (from scikit-image) (0.4)

# %%
def watermark_image(input_path):
    #For some reason the globally imported dependencies weren't available in this function so we use the global keyword to tell the compiler we are referring to them
    global cv2, np, plt, os, hashlib, bchlib, binascii, bitarray, structural_similarity

    # Read the image in grayscale mode and store it as a NumPy array(where each element represents the pixel intensity stored as an 8 bit unsigned integer ranging from 0-255) in input_image
    input_image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Check if image was successfully loaded
    if input_image is None:
        raise ValueError("Image not found or path is incorrect.")

    ## Step 2 of 7: Drawing a black Boundary on the input image, in this case the black boundary is just at the edge of the of image
    # Make a copy of the input image so we don't overwrite the original
    image_boundary = input_image.copy()

    # Drawing a black border (1 pixel wide) on all sides of the image by putting the intensity to 0(Black)
    image_boundary[0, :] = 0             # Top row
    image_boundary[-1, :] = 0            # Bottom row
    image_boundary[:, 0] = 0             # Left most column
    image_boundary[:, -1] = 0            # Right most column

   

    ## Step 3 of 7: Use OpenCV's built-in Otsu's method to compute threshold & Step 4 of 7: Turn all pixels greater than T_final white to get binarized_image
    # cv2.threshold returns both threshold and the binarized image
    # All pixels > Tfinal → 255 (white), else → 0 (black)
    T_final, binarized_image  = cv2.threshold(
        image_boundary,      # Input image (must be grayscale)
        0,             # Initial threshold value (ignored when using Otsu)
        255,           # Max value to use in binary thresholding
        cv2.THRESH_BINARY + cv2.THRESH_OTSU #Tells opencv to perform binary thresholding with otsu's method
    )

    ## Step 5 of 7: Find the seed pixels
    # The lungs are dark, and were kept black (0) after binarization.
    #In each of the 4 Quadrants of the image, We're looking for the first black pixel — that’s your seed for that quadrant.

    height, width = binarized_image.shape #Storing the height and width 
    margin = 1 # Setting margin of 1 since edges are the black boundary itself(1st pixel), so we start from pixel on the inside edge of the black boundary

    # Lines dividing the four quadrants
    mid_row = height // 2
    mid_col = width // 2

    seeds = {} # making a dictionary to store the seeds for each quadrant

    # Quadrant 1: Upper-left (start from left edge of center row of Quadrant 1, move right)
    row_q1 = height // 4 
    for x in range(margin, mid_col):
        if binarized_image[row_q1, x] == 0:# The first black pixel we encounter
            seeds['upper_left'] = (row_q1, x)# storing the seed
            print("Upper-left seed:", seeds['upper_left'])# Printing the seed
            break

    # Quadrant 2: Lower-left (start from left edge of center row of Quadrant 2, move right)
    row_q2 = 3 * height // 4
    for x in range(margin, mid_col):
        if binarized_image[row_q2, x] == 0:
            seeds['lower_left'] = (row_q2, x)# storing the seed
            print("Lower-left seed:", seeds['lower_left'])# Printing the seed
            break

    # Quadrant 3: Upper-right (start from right edge of center row of Quadrant 3, move left)
    row_q3 = height // 4
    for x in range(width - 1 - margin, mid_col, -1):
        if binarized_image[row_q3, x] == 0:# The first black pixel we encounter
            seeds['upper_right'] = (row_q3, x)# storing the seed
            print("Upper-right seed:", seeds['upper_right'])# Printing the seed
            break

    # Quadrant 4: Lower-right (start from right edge of center row of Quadrant 4, move left)
    row_q4 = 3 * height // 4
    for x in range(width - 1 - margin, mid_col, -1):
        if binarized_image[row_q4, x] == 0:# The first black pixel we encounter
            seeds['lower_right'] = (row_q4, x)# storing the seed
            print("Lower-right seed:", seeds['lower_right'])# Printing the seed
            break


    ## Printing the 4-Quadrant Image with seeds
    import cv2
    import matplotlib.pyplot as plt

    # Assuming binarized_image and seeds dictionary already exist

    # Convert image to RGB so we can draw colored markers
    image_rgb = cv2.cvtColor(binarized_image * 255, cv2.COLOR_GRAY2RGB)

    # Draw a red dot at each seed
    for key, (row, col) in seeds.items():
        cv2.circle(image_rgb, (col, row), radius=5, color=(255, 0, 0), thickness=-1)

    # Draw lines to split into 4 quadrants
    height, width = binarized_image.shape
    mid_row = height // 2
    mid_col = width // 2
    cv2.line(image_rgb, (0, mid_row), (width, mid_row), color=(0, 255, 0), thickness=1)
    cv2.line(image_rgb, (mid_col, 0), (mid_col, height), color=(0, 255, 0), thickness=1)

    ## Step 6: Creating a tagged image
    tagged_image = np.where(binarized_image == 255, 1, 0).astype(np.uint8)

    ## Step 7 of 7: Growing region from Seeds
    # Basically starts at a seed and expands to make the successive neighbours black, which were black in the tagged_image

    # Make a white copy of the image to draw the lungs on basically
    result_image = np.ones_like(binarized_image, dtype=np.uint8) * 255

    # Mask to keep track of visited pixels
    visited = np.zeros_like(tagged_image, dtype=bool)

    # 4-connected neighbor directions(above, below, left, right)
    neighbors = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    from collections import deque # importing deque for BFS basically 

    # Loop through all 4 quadrant seeds
    for seed_name in seeds:  # seeds is a dict with 4 quadrant seeds
        seed = seeds[seed_name]#seeds stores the location of the seeds for that quadrant
        if not visited[seed]:  # In case overlapping regions exist, we check if the current seeds has been visited in some other quadrants region expansion
            queue = deque([seed])# initialize the double ended queue with the seed
            visited[seed] = True # Mark the seed as True in the visited mask

            while queue:# Goes until the queue is empty
                y, x = queue.popleft()# retrieves the element from the begining of the queue
                result_image[y, x] = 0# Makes the element black

                for dy, dx in neighbors:#Iterates over 4 neighbours of the currently popped element
                    ny, nx = y + dy, x + dx# Location of current neighbour 
                    if (0 <= ny < result_image.shape[0]) and (0 <= nx < result_image.shape[1]): #Just a bound check to make sure the current location is inside the picture
                        if not visited[ny, nx] and tagged_image[ny, nx] == 0:# Checks that this neighbour/pixel hasn't been visited and it was black in the tagged/binarized image
                            queue.append((ny, nx))# Adds neighbour to the queue for its successive neighbour checks and making it black in the result_image
                            visited[ny, nx] = True# sets the neighbour as True in the visited mask


    ## Step 1
    # Setting LSBs of all pixels to zero
    lsb_zeroed_image = input_image.copy()  # creating a copy of the input_image loaded in the beginning
    lsb_zeroed_image = lsb_zeroed_image & 0b11111110  # Mask LSB to 0,  & 0b11111110 performs Bitwise AND operator between each element of the numpy array and 0b11111110, essentially setting last digit of each element to zero

    #Flattening the image into a byte stream sutiable for hashing
    flattened_bytes = lsb_zeroed_image.flatten().tobytes()#.flatten converts the 2D array to 1D array, /tobytes() converts all elements from int to byte form(1 byte can store upto 8 bits(255) info)

    #Computing SHA-512 hash as 128 character hexadecimal sequence(SHA-512 hash gives 512-bit = 128(512/4) hex characters)
    hash_hex = hashlib.sha512(flattened_bytes).hexdigest()  # hexdigest gives the output a hexadecimal representation

    #Converting the hex sequence to ASCII value in binary to get the watermark

    binary_representation = ''.join(f'{ord(char):08b}' for char in hash_hex)  

    #Printing the output
    print(f"SHA-512 Hash Output(Hexadecimal): {hash_hex}")
    print(f"Binary Representation of SHA-512 Hash: {binary_representation}")
    print(f"The length of the binary representation is: {len(binary_representation)}")

    ## Step 2: Srambling the identified RONI pixels in the original Image

    # Define the key (seed value) for reproducibility
    key = 42  # You can change this value to any integer, Ideally even this should be made using a PRNG

    # Basically we are fixing the seed used by np.random() function as "key"
    np.random.seed(key)

    # Making a copy of the original image to scramble
    scrambled_image = input_image.copy()

    # result_image is the final ROI and RONI separated image. 
    # Extracting coordinates of RONI pixels (value = 255)
    roni_coords = np.column_stack(np.where(result_image == 255)) # 2D array where each row represents a coordinate or pixel value=255

    # Extract the pixel values at those RONI positions in input_image
    roni_values = input_image[roni_coords[:, 0], roni_coords[:, 1]]


    # Shuffles the order of intensity values of RONI pixels stored in roni_values in place
    np.random.shuffle(roni_values)

    # Reassign shuffled values back to all RONI positions
    scrambled_image[roni_coords[:, 0], roni_coords[:, 1]] = roni_values

    print(f"Number of RONI pixels: {len(roni_coords)}")
   
    ## Step 3: Embed Watermark in Scrambled RONI

    # In case BCH does not work out, we consider the binary hash as the watermark to be embedded
    bin_watermark = binary_representation

    # Ensure the watermark to be embedded is 1024 bits (from BCH encoding or direct hash)
    assert len(bin_watermark) == 1024, "Error: Watermark to be embedded must be 256 bits."

    # Convert the watermark binary string to a list of integers (0s and 1s)
    watermark_bits = [int(bit) for bit in bin_watermark]

    # Check the number of total available RONI pixels
    num_roni_pixels = len(roni_coords)

    # Sanity check: Ensure there's at least one RONI pixel
    if num_roni_pixels == 0:
        raise ValueError("No RONI pixels available for embedding.")

    WM_coords = roni_coords[:1024]# Selecting the first 1024 rows of coordinates from the RONI coordinates list to embed the watermark into

    # Embed the watermark bits in the LSBs of the selected RONI pixels of scrambled_image
    for idx, bit in enumerate(watermark_bits):
        roni_x, roni_y = WM_coords[idx]# Each row of WM_coords would give us x and y coordinate of the RONI pixel we want to embed the watermark into 
        pixel_value = scrambled_image[roni_x, roni_y]# Retrieve the pixel value of the Watermark Coordinate

        # Modify the LSB
        new_pixel_value = (pixel_value | 1) if bit == 1 else (pixel_value & 0xFE)# If the bit to be embedded is 1, 

        scrambled_image[roni_x, roni_y] = new_pixel_value

    ## Step 4: Unscramble the pixels in RONI to take them back to original position, and display final Watermarked image

    # The key used is the same but we need to Re-seed to the RNG of Numpy to the bring it to the same state as it was when shuffling/scrambling the roni_coords
    np.random.seed(key)

    # Making Index array for helping with getting original order back
    original_indices = np.arange(num_roni_pixels) #np.arange() give a numpy array with values ranging form 0 to num_roni_pixels-1
    shuffled_indices = original_indices.copy() #making copy to shuffling 
    np.random.shuffle(shuffled_indices) # Shuffled

    # Computing inverse permutation using argsort
    reverse_indices = np.argsort(shuffled_indices)# np.argsort() gives an array of indices corresponding to values of shuffled_indices that would result in an ascending/sorted order

    # At this point RONI coordinates in scrambled_image has their values shuffled and then watermark embedded in the first 256 elements in the roni_coordinates list 
    # Extracting RONI values from the scrambled image
    embedded_roni_values = scrambled_image[roni_coords[:, 0], roni_coords[:, 1]]

    # Restoring order of values roni_values as it were before shuffling
    descrambled_values = embedded_roni_values[reverse_indices]

    # Assigning descrambled values to RONI coordinates in the image 
    scrambled_image[roni_coords[:, 0], roni_coords[:, 1]] = descrambled_values

    ## Sanity Check of Structural Similarity to see that the watermark has been embedded
    ssim = structural_similarity(input_image, scrambled_image, data_range=scrambled_image.max() - scrambled_image.min())
    print("Structural Similarity Index", ssim)

    return scrambled_image

# ===SCRIPT CONFIGURATION=====
input_folder="datasets/ctscan/raw/non-COVID"
output_folder="datasets/ctscan/RONI Watermarked/non-COVID"

# Process all images
for filename in os.listdir(input_folder): #go through all files in input_folder
    if filename.lower().endswith((".png")):#If the file name ends with .png
        input_path = os.path.join(input_folder, filename) # Appropriate input_path for the image
        output_path = os.path.join(output_folder, filename)# Appropriate output_path for the watermarked image

        
        try:
            output_image = watermark_image(input_path)
            cv2.imwrite(output_path, output_image)
            print(f"Processed: {filename} → {output_path}")
        except ValueError as e:
            print(e)
# Out:
# Upper-left seed: (36, 49)
# Lower-left seed: (108, 49)
# Upper-right seed: (36, 186)
# Lower-right seed: (108, 186)
# SHA-512 Hash Output(Hexadecimal): 6a9119505bc647224f73b0ba84c1a36eae2f687abfe266488a60127c77407fd95a2e091ef99139e72e97eb6165943f5b5aa77171f000a38c028f42a34d01e30b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 24829
# Structural Similarity Index 0.9998509905255235
# Processed: Covid (640).png → datasets/ctscan/RONI Watermarked/COVID/Covid (640).png
# Upper-left seed: (55, 29)
# Lower-left seed: (165, 26)
# Upper-right seed: (55, 306)
# Lower-right seed: (165, 308)
# SHA-512 Hash Output(Hexadecimal): 525413c3cc90e8cd1cabb8c065ad2c77f7743110743c7a4e8979a87b3123e42c34049f51576f74ec5a820201a86ce8698c5d648547b174f8c48684045512e299
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 33828
# Structural Similarity Index 0.9999654688550739
# Processed: Covid (210).png → datasets/ctscan/RONI Watermarked/COVID/Covid (210).png
# Upper-left seed: (73, 44)
# Lower-left seed: (219, 37)
# Upper-right seed: (73, 337)
# Lower-right seed: (219, 335)
# SHA-512 Hash Output(Hexadecimal): 2df1037db23b7c1589b1a373aa129333ba88e7861cd1d9b99b6ab9bb951300e6c8d0256f581f063e05e5ef1c642daff0f921ea17a2312fddb1403bee76952024
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 67199
# Structural Similarity Index 0.9999772517444274
# Processed: Covid (705).png → datasets/ctscan/RONI Watermarked/COVID/Covid (705).png
# Upper-left seed: (70, 32)
# Lower-left seed: (211, 39)
# Upper-right seed: (70, 359)
# Lower-right seed: (211, 358)
# SHA-512 Hash Output(Hexadecimal): 334c8d874ef59cbb74a1dd7a4acab1e1baca6127ff9717ce0cc1a23774c63bb8ac5d229e12c3d51df6564d17a9ceaa1767cde78069864afc77e49fc0df0cfd5b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 55501
# Structural Similarity Index 0.9999592332008583
# Processed: Covid (355).png → datasets/ctscan/RONI Watermarked/COVID/Covid (355).png
# Lower-right seed: (139, 174)
# SHA-512 Hash Output(Hexadecimal): 8048c5f550e33e7c1252332dbd3d2d5dd710abd01e57da3d0d79f3b2d2d99b197a6b7d8870818f33c6a13f876636b5b22e4abeda9fae61228165f92ce23e472c
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 39481
# Structural Similarity Index 0.9998721446012888
# Processed: Covid (586).png → datasets/ctscan/RONI Watermarked/COVID/Covid (586).png
# Lower-left seed: (204, 9)
# Upper-right seed: (68, 343)
# Lower-right seed: (204, 341)
# SHA-512 Hash Output(Hexadecimal): bc6b09ca1c72c5e531f216a2e24f49fb399f5bf483cda4c28d0416963ef1a21ad0473788afb0e324c7e4c36e256623423d15d7b4c451ff861ba84d15b9efbdbd
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 84135
# Structural Similarity Index 0.999923049996234
# Processed: Covid (1117).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1117).png
# Upper-left seed: (66, 17)
# Lower-left seed: (198, 10)
# Upper-right seed: (66, 353)
# Lower-right seed: (198, 321)
# SHA-512 Hash Output(Hexadecimal): d601be9cfb1793b75e5d18863063317a2b977da0bf4e622dd8d1ef9dcc01f18d7736ec7db6edd33c467142875d4aa1392a50794ddf9a2af552094fcd63f66f6e
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 55610
# Structural Similarity Index 0.9999741010314777
# Processed: Covid (91).png → datasets/ctscan/RONI Watermarked/COVID/Covid (91).png
# Upper-left seed: (79, 44)
# Lower-left seed: (237, 27)
# Upper-right seed: (79, 325)
# Lower-right seed: (237, 316)
# SHA-512 Hash Output(Hexadecimal): 15d4d06fdc4433636f54891b93077aafe17ac099d692d98f291f5003d3b518ff67f5dc3c1f224801beec466181e5dbdd2c88c7319bdc3482731e79bd0b78cef1
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 85094
# Structural Similarity Index 0.999979107697234
# Processed: Covid (990).png → datasets/ctscan/RONI Watermarked/COVID/Covid (990).png
# Upper-left seed: (54, 20)
# Lower-left seed: (162, 17)
# Upper-right seed: (54, 274)
# Lower-right seed: (162, 261)
# SHA-512 Hash Output(Hexadecimal): ddfe7dcec848363e267e51874c910812de1f1f16d4c5e3d555adee2c154ab282a46863fdd640c1054ff33ecc48168a9b29ba5e0d1528551bb97112ab90de9fb0
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 38263
# Structural Similarity Index 0.9999832102398033
# Processed: Covid (139).png → datasets/ctscan/RONI Watermarked/COVID/Covid (139).png
# Upper-left seed: (51, 39)
# Lower-left seed: (155, 45)
# Upper-right seed: (51, 227)
# Lower-right seed: (155, 215)
# SHA-512 Hash Output(Hexadecimal): 83cebdfa50ae67f84405243dbca8f09425ff224f8412fba49afd26c44542ded8de33fd5510d2e321090226d767cf9e37bcd70516ab0c87eb889d1281c16408f1
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 40422
# Structural Similarity Index 0.9998912515624669
# Processed: Covid (569).png → datasets/ctscan/RONI Watermarked/COVID/Covid (569).png
# Upper-left seed: (49, 50)
# Lower-left seed: (147, 19)
# Lower-right seed: (147, 212)
# SHA-512 Hash Output(Hexadecimal): c6ba787a0056b9685a6a00a5ec5df519b12a14aca1daa89d12074ed5a9891e27adb371cf1a6447ae008b3423e013d176426b4953b15c6543f444c124a5c6a3e6
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 31511
# Structural Similarity Index 0.9999516887283936
# Processed: Covid (1052).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1052).png
# Upper-left seed: (64, 38)
# Lower-left seed: (194, 37)
# Lower-right seed: (194, 281)
# SHA-512 Hash Output(Hexadecimal): 35f4c6331a0c3712eb49af552cabdb139733dff9e5be5aa90c98665ebb6567a7a19bf7e28deca41fe1c79e5a13963cac545f47fcc4bad851bf7bedd710bfed60
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 71957
# Structural Similarity Index 0.9999850703197347
# Processed: Covid (247).png → datasets/ctscan/RONI Watermarked/COVID/Covid (247).png
# Upper-left seed: (55, 29)
# Lower-left seed: (165, 12)
# Upper-right seed: (55, 234)
# Lower-right seed: (165, 246)
# SHA-512 Hash Output(Hexadecimal): b7dee53a10eab09012c656fc097caa840d831658a9cef3d4793e92fc2d3dc9fa9bba1c8c26e49526a32ff6cffb4e9e49a227ee4f2d37654aad947b2b09e675fa
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 35700
# Structural Similarity Index 0.9999045226805969
# Processed: Covid (617).png → datasets/ctscan/RONI Watermarked/COVID/Covid (617).png
# Upper-left seed: (53, 28)
# Lower-left seed: (160, 16)
# Upper-right seed: (53, 274)
# Lower-right seed: (160, 283)
# SHA-512 Hash Output(Hexadecimal): db925ea7f2e5c92c81316de61b0857f882bc5dd2e3909224f4337e8b1daf8420b3efb80e0f6ab85cc7a395b974d170cb54cbaf709fb3d42b55ecaa63e63b5b43
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 33433
# Structural Similarity Index 0.9999718483978312
# Processed: Covid (302).png → datasets/ctscan/RONI Watermarked/COVID/Covid (302).png
# Lower-left seed: (231, 23)
# Lower-right seed: (231, 389)
# SHA-512 Hash Output(Hexadecimal): 77844c2f519c125a79a6d374edd23b62901e65d6d0803ec3fed137636dc2666596fd7b2bdae51092de57175fd2be6492f91db59714a5ac52ba37931a00b6898a
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 115920
# Structural Similarity Index 0.9999525009059599
# Processed: Covid (752).png → datasets/ctscan/RONI Watermarked/COVID/Covid (752).png
# Upper-left seed: (47, 69)
# Lower-left seed: (141, 50)
# Upper-right seed: (47, 262)
# Lower-right seed: (141, 278)
# SHA-512 Hash Output(Hexadecimal): 59099372341aad4268fa34402edd55551903a7f817b356ad5f71bb50f51c0f02579a7696148ae5d04f94694451e6c87cd4a35f6ee9e209136b6cf292624d73ec
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 37471
# Structural Similarity Index 0.9999512208445107
# Processed: Covid (882).png → datasets/ctscan/RONI Watermarked/COVID/Covid (882).png
# Upper-left seed: (72, 11)
# Lower-left seed: (216, 4)
# Upper-right seed: (72, 339)
# Lower-right seed: (216, 341)
# SHA-512 Hash Output(Hexadecimal): a95b925bb453394dbaf7f8fba25ebf4bce5fb2dea6244b36a7b3b2992dd7daea6fda33ae7681fc882c5143af703df45fa1370e0397bc836e2a4bb2db36c6447d
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 49880
# Structural Similarity Index 0.9999702761451972
# Processed: Covid (928).png → datasets/ctscan/RONI Watermarked/COVID/Covid (928).png
# Upper-left seed: (60, 17)
# Lower-left seed: (181, 20)
# Upper-right seed: (60, 323)
# Lower-right seed: (181, 311)
# SHA-512 Hash Output(Hexadecimal): 63a8d75825bb8b90d81245f39c3324ad33654aa73abaf1124fac1f942971c1f36541777c37aad73d2661cccb7055ced7c6a8f2a1e816add7b7365b75ad981b10
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 43946
# Structural Similarity Index 0.999931386065169
# Processed: Covid (1140).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1140).png
# Upper-left seed: (67, 26)
# Lower-left seed: (201, 24)
# Upper-right seed: (67, 336)
# Lower-right seed: (201, 335)
# SHA-512 Hash Output(Hexadecimal): e56b3e8c1deb5a9f20328498d3f3b4c6c200ec26d3827da51741aa29b9034f8a276c8adfb7b1267d369bb559ab06c8ce7de0360bbe9c0c4defcc459a167b8b55
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 52314
# Structural Similarity Index 0.9999742959922197
# Processed: Covid (181).png → datasets/ctscan/RONI Watermarked/COVID/Covid (181).png
# Upper-left seed: (79, 41)
# Lower-left seed: (237, 13)
# Upper-right seed: (79, 298)
# Lower-right seed: (237, 292)
# SHA-512 Hash Output(Hexadecimal): 566b9de6d0fa81fa180f7ee4e2994006d87a187187d5ede374c012d3f0217420169948eb4ada45bf7c746115b588f9db3aeb750efcddd618f0b89fce3e145183
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 75457
# Structural Similarity Index 0.9999847860860538
# Processed: Covid (1005).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1005).png
# Upper-left seed: (62, 41)
# Lower-left seed: (188, 41)
# Upper-right seed: (62, 274)
# Lower-right seed: (188, 279)
# SHA-512 Hash Output(Hexadecimal): 60e13b8dc9c9505804cb56b727d06ad30b122a9f23ccdc76436d87b82798f9c719883c97d07e528e1e070fd65e9b63609adebaa91f88bbaa67b5bddfe1488826
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 53370
# Structural Similarity Index 0.9999430131234999
# Processed: Covid (494).png → datasets/ctscan/RONI Watermarked/COVID/Covid (494).png
# Upper-left seed: (55, 14)
# Lower-left seed: (167, 18)
# Upper-right seed: (55, 260)
# Lower-right seed: (167, 261)
# SHA-512 Hash Output(Hexadecimal): 8344cece8ddeced70a0650036a1936faa5cbbe34dfc93314431dae0965d5e154fe53ee9c6576c3e0c49c53181df6324e3c53a8771f3460cfd056303f994da837
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 35656
# Structural Similarity Index 0.999915542953373
# Processed: Covid (29).png → datasets/ctscan/RONI Watermarked/COVID/Covid (29).png
# Upper-left seed: (57, 26)
# Lower-left seed: (171, 14)
# Lower-right seed: (171, 265)
# SHA-512 Hash Output(Hexadecimal): f67e269aff7b1cf1be8c03047555179030fdf191f1d1ac0cdf6eddc987e695cd3aec25ffe482222fbc1e7c7c10194a04b98d4e4c16c68d00a1bb25d993dae5e7
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 55186
# Structural Similarity Index 0.9998967924959771
# Processed: Covid (601).png → datasets/ctscan/RONI Watermarked/COVID/Covid (601).png
# Upper-left seed: (66, 50)
# Lower-left seed: (198, 50)
# Lower-right seed: (198, 265)
# SHA-512 Hash Output(Hexadecimal): 30773e4cdd1f3a01b79335e8c4558a785575f97afb2766c2bdcd27352bbe2f14a4fd4e1f4367ddb1c61a7602b5d218eed0f03e8e513e799781b80dadafb5b5ea
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 82201
# Structural Similarity Index 0.9999836203304409
# Processed: Covid (251).png → datasets/ctscan/RONI Watermarked/COVID/Covid (251).png
# Upper-left seed: (53, 56)
# Lower-left seed: (161, 33)
# Upper-right seed: (53, 260)
# Lower-right seed: (161, 272)
# SHA-512 Hash Output(Hexadecimal): a45902d7ebe82d23a9602225405047e273ed7da157726401b3be5028603c99d6c2e83e21612af32779620b5f9b67b78960d2cff230d130f72eb64471f85cecc2
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 40925
# Structural Similarity Index 0.9999703878469293
# Processed: Covid (744).png → datasets/ctscan/RONI Watermarked/COVID/Covid (744).png
# Upper-left seed: (63, 46)
# Lower-left seed: (191, 45)
# Upper-right seed: (63, 361)
# Lower-right seed: (191, 363)
# SHA-512 Hash Output(Hexadecimal): a881393710271189399de0c31bce945f392d114c7e6e6cebd7afab9e4cdfdb289989644ff052b74cf547d0968db2dee9d1b68d550328fdd51d98d264d342b764
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 48664
# Structural Similarity Index 0.9999814110266785
# Processed: Covid (314).png → datasets/ctscan/RONI Watermarked/COVID/Covid (314).png
# Upper-left seed: (54, 40)
# Lower-left seed: (164, 30)
# Upper-right seed: (54, 285)
# Lower-right seed: (164, 294)
# SHA-512 Hash Output(Hexadecimal): fd937ce47dbec74c42e555bc1f369fa29244e0dbe166d5291c958e36ecb2a8b4c2d12bc3e396395788f49301399a03c85796bc5a8c94dc0e511e58d90527f170
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 33514
# Structural Similarity Index 0.9999651040562798
# Processed: Covid (197).png → datasets/ctscan/RONI Watermarked/COVID/Covid (197).png
# Lower-left seed: (196, 22)
# Upper-right seed: (65, 357)
# Lower-right seed: (196, 360)
# SHA-512 Hash Output(Hexadecimal): aadfc39ae547841d600ad964f303e9f139f69655e8bd310044cf426538ef4322e5893c7fe386c50daa0d65c52d5f2d93f7678e06747b5e03929af1f1b14df530
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 83430
# Structural Similarity Index 0.9999050585599893
# Processed: Covid (1156).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1156).png
# Upper-left seed: (63, 30)
# Lower-left seed: (189, 32)
# Upper-right seed: (63, 300)
# Lower-right seed: (189, 306)
# SHA-512 Hash Output(Hexadecimal): 9fae23955d97d10095bea09f39d64560a9c74868a48bd35f37c371744db8a2a3fe238b6b8426afbabc7880a38c0327fd2ab63967f10d43ed6ced68fe0af05ad8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 42558
# Structural Similarity Index 0.9999689719964349
# Processed: Covid (894).png → datasets/ctscan/RONI Watermarked/COVID/Covid (894).png
# Upper-left seed: (63, 40)
# Lower-left seed: (189, 34)
# Upper-right seed: (63, 342)
# Lower-right seed: (189, 344)
# SHA-512 Hash Output(Hexadecimal): 5174f850a66086d67c77e6eafa579a7ea712ac5a3337082d851962e126cf20e6f2c291a27f2ab8fe307022d7a88ebbc3c719188a1c93fcf3e24f04518e8be742
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 46655
# Structural Similarity Index 0.9999753490489487
# Processed: Covid (178).png → datasets/ctscan/RONI Watermarked/COVID/Covid (178).png
# Upper-left seed: (62, 34)
# Lower-left seed: (188, 42)
# Upper-right seed: (62, 290)
# Lower-right seed: (188, 295)
# SHA-512 Hash Output(Hexadecimal): 94029b355c70e4479f29d6cd435fcfbaf3db105e2808513a77bd359e4bdd5ef51c2db973fa3a3e1c428b07d8f6bc34aeda7713f079c961330e8322f603fd36cb
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 49902
# Structural Similarity Index 0.9999437877426234
# Processed: Covid (482).png → datasets/ctscan/RONI Watermarked/COVID/Covid (482).png
# Upper-left seed: (80, 47)
# Lower-left seed: (240, 20)
# Upper-right seed: (80, 308)
# Lower-right seed: (240, 300)
# SHA-512 Hash Output(Hexadecimal): 6eaf31142c6b5cd9ed5b362031905f22315be3493160886ad67b89d959b1df527e3886d73722848e8303989e0582be868709955c1bb48c51bdaefdac8d7d188d
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 80825
# Structural Similarity Index 0.9999855683956058
# Processed: Covid (1013).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1013).png
# Lower-left seed: (174, 32)
# Upper-right seed: (58, 268)
# Lower-right seed: (174, 277)
# SHA-512 Hash Output(Hexadecimal): 18bc138aa52dbbf9ebed71bf0885c1a822a38ea2b1777ac728e8a280f342322c34bbcee789455e2ebd2e6d5ed9d90bf8221d6e55dc6b725af16cb4e238cb0c75
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 62055
# Structural Similarity Index 0.9998803298027628
# Processed: Covid (528).png → datasets/ctscan/RONI Watermarked/COVID/Covid (528).png
# Upper-left seed: (58, 21)
# Lower-left seed: (176, 16)
# Upper-right seed: (58, 309)
# Lower-right seed: (176, 310)
# SHA-512 Hash Output(Hexadecimal): ffbf993ac93848c34240e71783df9bef42138bfe5d07893dc381dcfc2c151749175229357d40f74fe3f92c24b8cb0cc31765df0d11cb0926957a48a0b233e4f8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 38184
# Structural Similarity Index 0.9999697651818215
# Processed: Covid (206).png → datasets/ctscan/RONI Watermarked/COVID/Covid (206).png
# Upper-left seed: (53, 34)
# Lower-left seed: (160, 23)
# Upper-right seed: (53, 258)
# Lower-right seed: (160, 267)
# SHA-512 Hash Output(Hexadecimal): c45d8c9ec85e75e1131e21199f1c580df55f61dbba5cf378992e192a98c1bb2614f0d68c12534f9f04469547716f095d5e4cc430c544330316ba66888244f258
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 31315
# Structural Similarity Index 0.9999044434014343
# Processed: Covid (656).png → datasets/ctscan/RONI Watermarked/COVID/Covid (656).png
# Upper-left seed: (70, 50)
# Lower-left seed: (211, 46)
# Upper-right seed: (70, 333)
# Lower-right seed: (211, 343)
# SHA-512 Hash Output(Hexadecimal): 5d39bc08b85b8aed71fad34153a9174071fe7272db9f64b34ad9aefdfe7927f66c3334dd146b8a16d54c85d8c3a5f2544fab165de19dbd9072f5e57732e5d88b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 63102
# Structural Similarity Index 0.9999665443689381
# Processed: Covid (343).png → datasets/ctscan/RONI Watermarked/COVID/Covid (343).png
# Lower-right seed: (246, 365)
# SHA-512 Hash Output(Hexadecimal): be4e4eb40c1181848770ccd01c46d43cd32dc55a15bbe1b6c071bf6a2447c760f18beac41edadbe5184d96a1fa8b9136437d1feb9c07a78d85502f6826709a37
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 114178
# Structural Similarity Index 0.9999388636108261
# Processed: Covid (1228).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1228).png
# Upper-left seed: (69, 31)
# Lower-left seed: (207, 33)
# Upper-right seed: (69, 318)
# Lower-right seed: (207, 311)
# SHA-512 Hash Output(Hexadecimal): 63c411c252b2124669b6ac2900dae5635bf7a0e9966f8b1677bef5fd95f8e90f670544745b594b4c4e7bd87fcfcec22dc5a6fb5476afd2227e215e7f9210e3c2
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 46320
# Structural Similarity Index 0.9999705857620962
# Processed: Covid (713).png → datasets/ctscan/RONI Watermarked/COVID/Covid (713).png
# Upper-left seed: (65, 18)
# Lower-left seed: (197, 26)
# Upper-right seed: (65, 325)
# Lower-right seed: (197, 310)
# SHA-512 Hash Output(Hexadecimal): 453941125e5eb5ac3f382812b7e17080e28ed190f25a5d12fb563d612be333c1a80aa67afb4a5529483de752a82f2830f1ee5f8ab5d41b989284da1cfc05f2f2
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 59658
# Structural Similarity Index 0.9999718334702308
# Processed: Covid (87).png → datasets/ctscan/RONI Watermarked/COVID/Covid (87).png
# SHA-512 Hash Output(Hexadecimal): e5049d99ebb11b186b53671dd407c3c552ec337f0b5cf52401689c1d7256ac93fbb058429e9ef37b63c321218f435a6cdc717942dcd87e7d1978f0c484af6d9a
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 109664
# Structural Similarity Index 0.9999779010757226
# Processed: Covid (969).png → datasets/ctscan/RONI Watermarked/COVID/Covid (969).png
# Upper-left seed: (48, 33)
# Lower-left seed: (145, 12)
# Upper-right seed: (48, 246)
# Lower-right seed: (145, 265)
# SHA-512 Hash Output(Hexadecimal): 5872632e49bd351ffe012114dfd2bbf3a3a5874935d29b1c6094b68279657d393a1fcb6a661a0991a9dd31477a6f0ef64d2f6c38f4168af62829f3d96120b15e
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 25468
# Structural Similarity Index 0.9999230308055495
# Processed: Covid (1101).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1101).png
# Lower-left seed: (96, 28)
# Lower-right seed: (96, 161)
# SHA-512 Hash Output(Hexadecimal): e537a9ac544db52ce90cd2a82f553b12bfc4eee3191cd45853961d6b38d28f863b9702ee3c220685bc46daa4717d98637750dd034853719dc880ce0d8664b965
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 18144
# Structural Similarity Index 0.9997745626319449
# Processed: Covid (590).png → datasets/ctscan/RONI Watermarked/COVID/Covid (590).png
# Upper-left seed: (60, 36)
# Lower-left seed: (181, 28)
# Upper-right seed: (60, 234)
# Lower-right seed: (181, 244)
# SHA-512 Hash Output(Hexadecimal): 1ed46fa1ac584e781277eb39c8626f0088f5b9b8889f4ac209d330fb8d31cdb323e31fa9745a6778c2c58de7274a616548d966803a07cdea292672b3258a1d5a
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 42067
# Structural Similarity Index 0.99996722541807
# Processed: Covid (1044).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1044).png
# Upper-left seed: (79, 8)
# Lower-left seed: (238, 33)
# Upper-right seed: (79, 336)
# Lower-right seed: (238, 327)
# SHA-512 Hash Output(Hexadecimal): 56960d030266ea534be02e71f4c89c883e108d9efb6a0f10ff65ee99459028d1343c21237a2b8a34db362cf5aee79e20f73d536ddf70421dde5d5fcb1af247f9
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 96691
# Structural Similarity Index 0.9999823200145475
# Processed: Covid (986).png → datasets/ctscan/RONI Watermarked/COVID/Covid (986).png
# Upper-left seed: (57, 14)
# Lower-left seed: (171, 21)
# Upper-right seed: (57, 279)
# Lower-right seed: (171, 274)
# SHA-512 Hash Output(Hexadecimal): 68b248bd420687eaa58a78ecc82fcacbb3c950e6028989d92cd6e7500ca3992fa7136b50805020b5a3cbd6dd883785263b525e01e517c7831d15bf4bccc406e7
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 30038
# Structural Similarity Index 0.9999653438413348
# Processed: Covid (68).png → datasets/ctscan/RONI Watermarked/COVID/Covid (68).png
# Upper-left seed: (58, 17)
# Lower-left seed: (175, 22)
# Upper-right seed: (58, 316)
# Lower-right seed: (175, 315)
# SHA-512 Hash Output(Hexadecimal): d333e631cff120b89b5be7d76b6074b1d1019abbfc2f309f126358285babaedc5d2ea913da30f3bb95e5de1479aca4579dd952bf108f591e4c15f0fc6854c65b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 31072
# Structural Similarity Index 0.9999463625775458
# Processed: Covid (338).png → datasets/ctscan/RONI Watermarked/COVID/Covid (338).png
# Upper-left seed: (69, 30)
# Lower-left seed: (207, 34)
# Upper-right seed: (69, 362)
# Lower-right seed: (207, 349)
# SHA-512 Hash Output(Hexadecimal): 8fdd330b42c9d86c36a20bef44b49f299f8be3444f3dc6c75a3db5613f3e7121ca0709c85bc229dcc731bc6df1ab3bdf814212dd61b1e2de667b6ef230376b74
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 65168
# Structural Similarity Index 0.9999374414124205
# Processed: Covid (768).png → datasets/ctscan/RONI Watermarked/COVID/Covid (768).png
# Upper-left seed: (63, 26)
# Lower-left seed: (189, 20)
# Upper-right seed: (63, 275)
# Lower-right seed: (189, 270)
# SHA-512 Hash Output(Hexadecimal): d2ab03132f05c70e51fc0cd4ae0dab7c799848dd18b1aec39953c47bd242fa9ee14df8188004c92f4b907d66e811692f266f9f18db3ab4b926bc70367d3377e7
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 52810
# Structural Similarity Index 0.999961963958281
# Processed: Covid (292).png → datasets/ctscan/RONI Watermarked/COVID/Covid (292).png
# Upper-left seed: (68, 35)
# Lower-left seed: (204, 45)
# Upper-right seed: (68, 327)
# Lower-right seed: (204, 320)
# SHA-512 Hash Output(Hexadecimal): 4f40b1718e7926b9c76051efeceb7b615a1b5cbdd992f6512f5b13084928b9053582a3b48055f76d4e5271b954e4a7dd67f04c44725aec7aa08c4421b610a9bf
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 78637
# Structural Similarity Index 0.9999665367427213
# Processed: Covid (787).png → datasets/ctscan/RONI Watermarked/COVID/Covid (787).png
# Upper-left seed: (66, 28)
# Lower-left seed: (198, 29)
# Upper-right seed: (66, 316)
# Lower-right seed: (198, 312)
# SHA-512 Hash Output(Hexadecimal): d8a3c0f1135c1e9f7235484e23c12331b6ec1f4c28da6e96b93babecbed731e19b75815cbf14a21e92cf02500f32ae90e5b6399c9d8bd09f6cdf460fd8ab76ef
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 60794
# Structural Similarity Index 0.9999353982062689
# Processed: Covid (504).png → datasets/ctscan/RONI Watermarked/COVID/Covid (504).png
# Upper-left seed: (65, 21)
# Lower-left seed: (195, 16)
# Upper-right seed: (65, 351)
# Lower-right seed: (195, 357)
# SHA-512 Hash Output(Hexadecimal): 33f6bdf14dd6717257fcca0d2a97828f49b6875e42782a3622b502daf33421259f7fe3cff937c2ada2311e3fc10c58eb780eef266a7c2331449153c2ae6d414f
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 80745
# Structural Similarity Index 0.9999001729925295
# Processed: Covid (1195).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1195).png
# Upper-left seed: (67, 50)
# Lower-left seed: (203, 18)
# Upper-right seed: (67, 335)
# Lower-right seed: (203, 302)
# SHA-512 Hash Output(Hexadecimal): c92b391b7d2e4159d68ecf2406d3a8f342c9f0bd1d3c05ea88ccdce5ddff2a9f13b39b8850fae9877248d8c46f2cb0240c5549d04c043b6efb3e8734fd93981a
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 51839
# Structural Similarity Index 0.999987317330826
# Processed: Covid (154).png → datasets/ctscan/RONI Watermarked/COVID/Covid (154).png
# Upper-left seed: (48, 13)
# Lower-left seed: (145, 19)
# Upper-right seed: (48, 235)
# Lower-right seed: (145, 232)
# SHA-512 Hash Output(Hexadecimal): 9afe5de0b6bed7f9f477b06a6b5e69a883f5a8c7489ddb4802ac53b2f21ed32df16d601e5d36959897d467a5023f2e253483a78369a4c8f5daba4b963b524af1
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 24866
# Structural Similarity Index 0.9998956599216888
# Processed: Covid (13).png → datasets/ctscan/RONI Watermarked/COVID/Covid (13).png
# Upper-left seed: (69, 23)
# Lower-left seed: (207, 26)
# Upper-right seed: (69, 321)
# Lower-right seed: (207, 323)
# SHA-512 Hash Output(Hexadecimal): c85e3dff834550a6fc0e7dd336648c8276ffcd9d50b4a4bce2123a0deb966723552751450adfde6443453843dc9d4a6f1db6dfc4c8addd7697d471c1b7efa63f
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 46208
# Structural Similarity Index 0.9999751411540203
# Processed: Covid (857).png → datasets/ctscan/RONI Watermarked/COVID/Covid (857).png
# Upper-left seed: (74, 24)
# Lower-left seed: (222, 11)
# Upper-right seed: (74, 403)
# Lower-right seed: (222, 374)
# SHA-512 Hash Output(Hexadecimal): 086fcceea61405692006f49f7b4227c86f84dce781bda45f326ea5613c0cc06d25e8146b69e6d988414e3b3037e82269116fcec3637b333d4db9d04c691ab70a
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 85811
# Structural Similarity Index 0.9999701596497609
# Processed: Covid (912).png → datasets/ctscan/RONI Watermarked/COVID/Covid (912).png
# Upper-left seed: (80, 43)
# Lower-left seed: (241, 30)
# Upper-right seed: (80, 319)
# Lower-right seed: (241, 321)
# SHA-512 Hash Output(Hexadecimal): b1eeb4d5b96605eef5eb841e316b63188c6062f907283f1c2fc369542857e3056f0d5cb28e67d8f686b5cf19824184838e01b6e6ab32321f74ab0e03fbdf9bc3
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 81459
# Structural Similarity Index 0.9999388768617089
# Processed: Covid (441).png → datasets/ctscan/RONI Watermarked/COVID/Covid (441).png
# Upper-left seed: (64, 29)
# Lower-left seed: (193, 24)
# Upper-right seed: (64, 350)
# Lower-right seed: (193, 358)
# SHA-512 Hash Output(Hexadecimal): 7ac999f1b77a36bebacdfc5fa9a7121b5eaa5a85e3a4bf90de2d3e5ab7d41fb51abe1408bbc018de911c9ccc1c16209a70ffe42199d54186550f8614e1e774c8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 55503
# Structural Similarity Index 0.9999237444077514
# Processed: Covid (1204).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1204).png
# Upper-left seed: (72, 54)
# Lower-left seed: (217, 41)
# Upper-right seed: (72, 346)
# Lower-right seed: (217, 359)
# SHA-512 Hash Output(Hexadecimal): 6f4bd73d014b8f34d5d00b4f1293b2eb318df2f4e55f35b10782894b87ca83718e991f03b3a36ae24fbef5f380bd8c6054e68a9afe8e0e5dde2d1a1ee60bcdec
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 72252
# Structural Similarity Index 0.999975749828448
# Processed: Covid (695).png → datasets/ctscan/RONI Watermarked/COVID/Covid (695).png
# Upper-left seed: (72, 36)
# Lower-left seed: (216, 46)
# Upper-right seed: (72, 354)
# Lower-right seed: (216, 341)
# SHA-512 Hash Output(Hexadecimal): bc56ec84e0d2e5d724c27776c379d2426e2362c9fabd2531fa5c9757f6338a70cfd0410a13e94d3999d7e9d0ad153ab3894f255ec0fbcc314419808504da4a22
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 68569
# Structural Similarity Index 0.9999811919069472
# Processed: Covid (380).png → datasets/ctscan/RONI Watermarked/COVID/Covid (380).png
# Upper-left seed: (61, 10)
# Lower-left seed: (183, 15)
# Upper-right seed: (61, 304)
# Lower-right seed: (183, 298)
# SHA-512 Hash Output(Hexadecimal): acd3ee628cef095e8abd78eedf7b156aafb13b90007f59f899a8e2bf474d1855b3da3d2c169a2561cf66a22baf999b171d7289f6ec217ca2887eb24d450a9ba4
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 34100
# Structural Similarity Index 0.9999678601236475
# Processed: Covid (44).png → datasets/ctscan/RONI Watermarked/COVID/Covid (44).png
# Upper-left seed: (60, 22)
# Lower-left seed: (182, 43)
# Upper-right seed: (60, 289)
# Lower-right seed: (182, 301)
# SHA-512 Hash Output(Hexadecimal): cd03c49fa6a4bc94113704e6a5319cde594e00f4fc336fbfd879ed7fe0eb6c2b8489fce554efd535d0259b34c3c88353c1730b03c1074bd26f446c05d2d3eb38
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 46438
# Structural Similarity Index 0.999961227420704
# Processed: Covid (800).png → datasets/ctscan/RONI Watermarked/COVID/Covid (800).png
# Upper-left seed: (63, 25)
# Lower-left seed: (190, 36)
# Upper-right seed: (63, 320)
# Lower-right seed: (190, 313)
# SHA-512 Hash Output(Hexadecimal): 529a7eaa60d833c9150d98639db29f3da0c91ec155b06d0c918757e1a0ae92d2d24b39097ad867c2c3687532586bc6adc914ccfa377cf0174b31891b6f9a4ba5
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 54520
# Structural Similarity Index 0.9999781766998362
# Processed: Covid (3).png → datasets/ctscan/RONI Watermarked/COVID/Covid (3).png
# Upper-left seed: (64, 15)
# Lower-left seed: (194, 15)
# Upper-right seed: (64, 330)
# Lower-right seed: (194, 330)
# SHA-512 Hash Output(Hexadecimal): b47e3938a8300ff0aef150cc8230b991d1727f99fdd8a9cdbf376e51e4bbb4f753efa9175868516635ecb10e4271b7c540b6fa4f403bc2ed28903a710efeecbc
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 40666
# Structural Similarity Index 0.9999802879698217
# Processed: Covid (103).png → datasets/ctscan/RONI Watermarked/COVID/Covid (103).png
# Upper-left seed: (72, 16)
# Lower-left seed: (216, 12)
# Upper-right seed: (72, 374)
# Lower-right seed: (216, 368)
# SHA-512 Hash Output(Hexadecimal): 6a99de38f8c7f378cb2cac4456ce36e9b9dcf1097d69e879bd038cbdaa1d6c01e8e5b20554467bffc289d21483314e23abbbc2d7f24692b4cc7ce376e0add5fa
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 57293
# Structural Similarity Index 0.999943725715376
# Processed: Covid (1068).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1068).png
# Upper-left seed: (48, 23)
# Lower-left seed: (146, 16)
# Upper-right seed: (48, 232)
# Lower-right seed: (146, 234)
# SHA-512 Hash Output(Hexadecimal): 88d026a3be9abcfaa38bfa83cb385168cb1eee37ac64a8362c3ab64b89b4b5842defb6adb06a9fd851e971ca68059d1e8ded1eda5423e9c9716890953a4913ae
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 38715
# Structural Similarity Index 0.9998879999319948
# Processed: Covid (553).png → datasets/ctscan/RONI Watermarked/COVID/Covid (553).png
# Upper-left seed: (65, 46)
# Lower-left seed: (196, 39)
# Upper-right seed: (65, 337)
# Lower-right seed: (196, 339)
# SHA-512 Hash Output(Hexadecimal): 60297d2c564375f76c5ffd78ee017a40c0659bc75bee96fecd8b7aee113ce3d636b0681d9a5e30cd47e84d94edd1be73f1c4eb329efd5a2250a7a348228ba785
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 49873
# Structural Similarity Index 0.9999458345279365
# Processed: Covid (1087).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1087).png
# Upper-left seed: (77, 1)
# Lower-left seed: (231, 23)
# Upper-right seed: (77, 380)
# Lower-right seed: (231, 332)
# SHA-512 Hash Output(Hexadecimal): 0469df8ae5a7b10753fa7dd247f2229eee8b0e5f99ea01c016f335095c1f9a2fb269a0249856aae65864e6c971a36d02005f911895c122702a02c36bdfb22ea3
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 60143
# Structural Similarity Index 0.9999256372954226
# Processed: Covid (416).png → datasets/ctscan/RONI Watermarked/COVID/Covid (416).png
# Upper-left seed: (71, 24)
# Lower-left seed: (215, 22)
# Upper-right seed: (71, 343)
# Lower-right seed: (215, 340)
# SHA-512 Hash Output(Hexadecimal): c6573b23f4f06ae143eaee2263189c607b347d31cdadc5ea6a913dbd09e90f592311822afd6851c2b89a91969502e577b74d03d763f518d7f456eecd027494b9
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 58286
# Structural Similarity Index 0.9999690407426226
# Processed: Covid (945).png → datasets/ctscan/RONI Watermarked/COVID/Covid (945).png
# Upper-left seed: (66, 31)
# Lower-left seed: (200, 38)
# Upper-right seed: (66, 349)
# Lower-right seed: (200, 340)
# SHA-512 Hash Output(Hexadecimal): 9583b0c1763cb400f9fcda5cb249ba8fd87522caced537ba0545fb0efc14abb66f83f4ed0d7ae2194be912316cccdc7cd3b4e5b315a84abcdc6adc95f5de7fe3
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 49248
# Structural Similarity Index 0.9999769815172995
# Processed: Covid (379).png → datasets/ctscan/RONI Watermarked/COVID/Covid (379).png
# Upper-left seed: (31, 45)
# Lower-left seed: (93, 33)
# Upper-right seed: (31, 152)
# Lower-right seed: (93, 163)
# SHA-512 Hash Output(Hexadecimal): 2d5a6ba35ba25bd9a69e6b3e1568d90b5e531515c71aca335e693a19d2d448e03f5778e73e8af4b8332eba31ae7a40a5fdc33c9cb50ffbfd9fdeff8e8708049b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 17155
# Structural Similarity Index 0.9997473806319385
# Processed: Covid (683).png → datasets/ctscan/RONI Watermarked/COVID/Covid (683).png
# Upper-left seed: (64, 47)
# Lower-left seed: (192, 39)
# Upper-right seed: (64, 300)
# Lower-right seed: (192, 311)
# SHA-512 Hash Output(Hexadecimal): 2f3c276e84b68f704784e92d9966873d4580d8cbc276d342ca181d797355b2619ebd954c3891635ff063e4bb28036aab0a1ab7b657f4f80d24e3a77a4d455f76
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 49053
# Structural Similarity Index 0.9999718435337435
# Processed: Covid (729).png → datasets/ctscan/RONI Watermarked/COVID/Covid (729).png
# Upper-left seed: (64, 17)
# Lower-left seed: (193, 14)
# Upper-right seed: (64, 329)
# Lower-right seed: (193, 330)
# SHA-512 Hash Output(Hexadecimal): 9756bcc7ec040390552dcc3ed2bd4beb1c8e15944fd567ef834d13b98e4b11100a63821fc6247a9e1ccbb97b7d76dbe2cf665a7bc9bd49e151fcfc6343d0dafc
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 43221
# Structural Similarity Index 0.9999183780435484
# Processed: Covid (1212).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1212).png
# Upper-left seed: (49, 13)
# Lower-left seed: (147, 12)
# Upper-right seed: (49, 223)
# Lower-right seed: (147, 221)
# SHA-512 Hash Output(Hexadecimal): 6dd79b974041a0935d864d1fb7449524492ad8282682a7901318593ed2842c360369567da3d3f6823f46af3c5793179645ebe3efadeadca52226cd58c5d8e732
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 22778
# Structural Similarity Index 0.9999599150384035
# Processed: Covid (396).png → datasets/ctscan/RONI Watermarked/COVID/Covid (396).png
# Upper-left seed: (55, 44)
# Lower-left seed: (165, 39)
# Upper-right seed: (55, 258)
# Lower-right seed: (165, 262)
# SHA-512 Hash Output(Hexadecimal): a6628afe5227ee33ed9357d724cc07cdc17d310187a1f5bee2618dda4d14ca805bb2db463effe1587b60e2c7ed592a2d12dd649c510f2668bea04869c52c9193
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 58060
# Structural Similarity Index 0.9998875481844214
# Processed: Covid (545).png → datasets/ctscan/RONI Watermarked/COVID/Covid (545).png
# Upper-left seed: (78, 25)
# Lower-left seed: (236, 24)
# Upper-right seed: (78, 360)
# Lower-right seed: (236, 363)
# SHA-512 Hash Output(Hexadecimal): 5b7a374ba93684e6c076ab038b951282382438d124b6a63420e8928bbd0cbf136fb99628210ce28eb84e0e6def18ef710221bed225b470a507299a108be71c5d
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 63617
# Structural Similarity Index 0.9999832347526936
# Processed: Covid (115).png → datasets/ctscan/RONI Watermarked/COVID/Covid (115).png
# Upper-left seed: (55, 23)
# Lower-left seed: (165, 22)
# Upper-right seed: (55, 282)
# Lower-right seed: (165, 287)
# SHA-512 Hash Output(Hexadecimal): 8e59ee237b6385ff0dd6da8ac795599eb4fdea4f07f4d22ab3aa49dbedaaeea1fa3a06b5b113ad149f0e6f81375e4b9c1edf69d6f1d03c116a62eb44081071ac
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 36318
# Structural Similarity Index 0.9999566734670506
# Processed: Covid (816).png → datasets/ctscan/RONI Watermarked/COVID/Covid (816).png
# Upper-left seed: (65, 31)
# Lower-left seed: (196, 22)
# Upper-right seed: (65, 328)
# Lower-right seed: (196, 323)
# SHA-512 Hash Output(Hexadecimal): ac8d1bb4571374af45acd10c2283cd03cdd55d7af365ac97f2135a85720a32aa2685b2c5e131a2e9e8bf3cb26530a903872c4be8522d023882fdc3f3f76f2d22
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 45549
# Structural Similarity Index 0.9999779696494212
# Processed: Covid (52).png → datasets/ctscan/RONI Watermarked/COVID/Covid (52).png
# Upper-left seed: (63, 21)
# Lower-left seed: (191, 23)
# Upper-right seed: (63, 337)
# Lower-right seed: (191, 332)
# SHA-512 Hash Output(Hexadecimal): 0c8b79aeaa1cd1ab20785a94f3650df8a92c55c126b57dca4f319dcec1359a7c31641df43db1149c173ec42d518f083c91d460bac90b4e4a3de13fb794a294fc
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 42737
# Structural Similarity Index 0.999965870445027
# Processed: Covid (953).png → datasets/ctscan/RONI Watermarked/COVID/Covid (953).png
# Upper-left seed: (52, 15)
# Lower-left seed: (158, 9)
# Upper-right seed: (52, 232)
# Lower-right seed: (158, 234)
# SHA-512 Hash Output(Hexadecimal): 2045edea2b13434c2a3598dd2af7e24da8c443e2b897fe4bfedfd0c4590fd07911f5fca6b5b82d2b9c1a4dbf61a32c0de6e262f4ec0a6a98b5fe94462cafd7c6
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 25581
# Structural Similarity Index 0.999961700963742
# Processed: Covid (400).png → datasets/ctscan/RONI Watermarked/COVID/Covid (400).png
# Upper-left seed: (61, 26)
# Lower-left seed: (185, 13)
# Upper-right seed: (61, 296)
# Lower-right seed: (185, 302)
# SHA-512 Hash Output(Hexadecimal): 0cd471b1df9ccf5197f77461bf9c87ccae576d234e91f62f7b77893f355a024678919386ccec08c5d346f5f7e215f5b4a7028f90a60e8007f2f510980fe112ff
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 35843
# Structural Similarity Index 0.9999330244764607
# Processed: Covid (1091).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1091).png
# Upper-left seed: (62, 40)
# Lower-left seed: (187, 25)
# Upper-right seed: (62, 268)
# Lower-right seed: (187, 271)
# SHA-512 Hash Output(Hexadecimal): e1bb0628831fea1b962d554e1db596fa3cc20027970f2c0d79ce96135fa39b37f7e31ab8db6cca12df1dac92cd0e066944a1b73120c7f52d002cf8c971ab45dc
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 48591
# Structural Similarity Index 0.9999633154540173
# Processed: Covid (284).png → datasets/ctscan/RONI Watermarked/COVID/Covid (284).png
# Upper-left seed: (77, 48)
# Lower-left seed: (233, 20)
# Upper-right seed: (77, 343)
# Lower-right seed: (233, 346)
# SHA-512 Hash Output(Hexadecimal): d032f2b293550f8c87f95ca02180909a795d3057c76148fee60ba822f929f80a134c04930d73b3f50432807bdd28c843cec3b782a52a903c594c32ff69af6f3d
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 72562
# Structural Similarity Index 0.9999296103672907
# Processed: Covid (1245).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1245).png
# Upper-left seed: (65, 45)
# Lower-left seed: (195, 65)
# Upper-right seed: (65, 319)
# Lower-right seed: (195, 334)
# SHA-512 Hash Output(Hexadecimal): d116339b3f68ff028481cdb595925aaab04dc3a1963c9697ee70fbdc177c5f54ee6dae9e71e523967f3bfccbe3ee361339a69ed3fef95b29a903b0a40d593fe0
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 68085
# Structural Similarity Index 0.9999646037180456
# Processed: Covid (791).png → datasets/ctscan/RONI Watermarked/COVID/Covid (791).png
# Upper-left seed: (72, 16)
# Lower-left seed: (217, 20)
# Upper-right seed: (72, 333)
# Lower-right seed: (217, 327)
# SHA-512 Hash Output(Hexadecimal): 36702c487cd83240797e0674cf4d3ae3b57fa9eca5709b47d6caaf3a3a287d6ce49f6f36bc8df471df84dec71d2bf8318ede3d7a4ba974d7a6a44a3afb57912c
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 54305
# Structural Similarity Index 0.9999724956289934
# Processed: Covid (841).png → datasets/ctscan/RONI Watermarked/COVID/Covid (841).png
# Upper-left seed: (63, 64)
# Lower-left seed: (189, 44)
# Upper-right seed: (63, 293)
# Lower-right seed: (189, 294)
# SHA-512 Hash Output(Hexadecimal): c6830d10773da5696cf892e714c57ea6a034c570ba8f2f043b4fce3f3fcafc7e7c12005a6cfc73cb52683d7dff2c1de53a9f63d14485f3d6be4f1d3706953b23
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 58351
# Structural Similarity Index 0.9999824562401327
# Processed: Covid (142).png → datasets/ctscan/RONI Watermarked/COVID/Covid (142).png
# Upper-left seed: (61, 13)
# Lower-left seed: (184, 28)
# Upper-right seed: (61, 310)
# Lower-right seed: (184, 286)
# SHA-512 Hash Output(Hexadecimal): eb8a4494edf0fdb6bfbc92ae6b4c9d88066cf7bc0421572c198dee8705e5a71de8be1d592b8cde6c1ea455826921ea8a85999d6e814d4edca6f254a3b7147f90
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 45162
# Structural Similarity Index 0.9999370419530154
# Processed: Covid (1183).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1183).png
# Upper-left seed: (66, 36)
# Lower-left seed: (198, 27)
# Upper-right seed: (66, 306)
# Lower-right seed: (198, 308)
# SHA-512 Hash Output(Hexadecimal): 123390e5a217a4a4ad1530fdd0d93d56dfecdfd613fe1fbb811714458461cf17e1207116aea0db5e1444fcf6ecc77b7d1932549228b556a27ef33f68c8afd4e1
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 60441
# Structural Similarity Index 0.9999454464925338
# Processed: Covid (512).png → datasets/ctscan/RONI Watermarked/COVID/Covid (512).png
# Upper-left seed: (66, 40)
# Lower-left seed: (200, 14)
# Upper-right seed: (66, 282)
# Lower-right seed: (200, 282)
# SHA-512 Hash Output(Hexadecimal): 545988bfb9a9bb63a8bc8e70a3c79e0f2458f8c98d8e70471ff119179fc24b4bf2b9db64667dd35aa29cafa036cfe91b9912bd71c165b9b477baee740a842667
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 57907
# Structural Similarity Index 0.999976320477833
# Processed: Covid (1029).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1029).png
# Upper-left seed: (62, 48)
# Lower-left seed: (186, 17)
# Upper-right seed: (62, 283)
# Lower-right seed: (186, 304)
# SHA-512 Hash Output(Hexadecimal): 58b786cab27aa5e818358356b09067eb96d26ce1a1aeb014d04c1cea37e89719f620a1d72476c0c03e17ffe5dd30cbecd3b62c21b83966ddc906b964d429e9d5
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 50468
# Structural Similarity Index 0.9999305383995649
# Processed: Covid (457).png → datasets/ctscan/RONI Watermarked/COVID/Covid (457).png
# Lower-left seed: (216, 10)
# Upper-right seed: (72, 403)
# Lower-right seed: (216, 382)
# SHA-512 Hash Output(Hexadecimal): 83d0ad7e00b5a736f95720f338c5e5ff55e977431c4679e738cd3386d2335b95833b6e8f5de349670f0fd464bcf77ae0ad7914b77228d52c6c0f01ba1c05a51d
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 103758
# Structural Similarity Index 0.9999698800184575
# Processed: Covid (904).png → datasets/ctscan/RONI Watermarked/COVID/Covid (904).png
# Lower-left seed: (247, 5)
# SHA-512 Hash Output(Hexadecimal): 2a0c481acb4b9afdeff81517afcf36248d9afbf1b9c468b69b399bf2698cec77463b57a7967ce9a40fb18f25ce8c664af56c36938db1bc6946f34c6f3940cb88
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 107528
# Structural Similarity Index 0.9999775412938633
# Processed: Covid (973).png → datasets/ctscan/RONI Watermarked/COVID/Covid (973).png
# Upper-left seed: (67, 1)
# Lower-left seed: (201, 23)
# Upper-right seed: (67, 296)
# Lower-right seed: (201, 322)
# SHA-512 Hash Output(Hexadecimal): dd6a2c00e2c29f2db6c474e330a1570b5c5804bb23207dbeee89813173b1371d6edb9c054d1ed982e0fc37436ea76ad1c892d5f264f57747f4f5899d70204ea1
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 43013
# Structural Similarity Index 0.9999100371691535
# Processed: Covid (420).png → datasets/ctscan/RONI Watermarked/COVID/Covid (420).png
# Upper-left seed: (48, 50)
# Lower-left seed: (144, 41)
# Upper-right seed: (48, 236)
# Lower-right seed: (144, 203)
# SHA-512 Hash Output(Hexadecimal): dada8a03ea75b02ddc3fd227046dab266a063817ee35117ebb6c93e32161160fb678ec9820cce1808ef7fa297bb888857b64afe3ade90752448cea9c0bd32923
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 54862
# Structural Similarity Index 0.9999339479239645
# Processed: Covid (1207).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1207).png
# Upper-left seed: (72, 58)
# Lower-left seed: (218, 46)
# Upper-right seed: (72, 351)
# Lower-right seed: (218, 361)
# SHA-512 Hash Output(Hexadecimal): 7d011b153d909b5ba0e3bd85fa24a1bbb15a31a6d5203e0637763356958f0be64c9bfbb4aadb83e5de05f547c2d6702f153500f69ed7bffed12d601ce7ad5b5b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 74921
# Structural Similarity Index 0.9999744433446046
# Processed: Covid (696).png → datasets/ctscan/RONI Watermarked/COVID/Covid (696).png
# Upper-left seed: (71, 17)
# Lower-left seed: (213, 24)
# Upper-right seed: (71, 337)
# Lower-right seed: (213, 326)
# SHA-512 Hash Output(Hexadecimal): a9a0e094e2abd029f6a3fdce3dea43be3ef86a27b35efe9ce62bd30693c30496b5abfac99996d9dc21e27cee3cae1a77e52cefae13fbd8cd07ac4d915f6a4ca4
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 53752
# Structural Similarity Index 0.9999711992964974
# Processed: Covid (946).png → datasets/ctscan/RONI Watermarked/COVID/Covid (946).png
# Upper-left seed: (66, 29)
# Lower-left seed: (199, 22)
# Upper-right seed: (66, 334)
# Lower-right seed: (199, 341)
# SHA-512 Hash Output(Hexadecimal): 7060b69c700e68c7794e8aaf530f8f12d6b784573ce6852fcd02c5e3f8b241463d9fce402b3a5256e33534a554345e227ea4fac259bab395d5014f279bb10f29
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 48950
# Structural Similarity Index 0.9999429888481356
# Processed: Covid (1084).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1084).png
# Upper-left seed: (72, 1)
# Lower-left seed: (218, 40)
# Upper-right seed: (72, 411)
# Lower-right seed: (218, 366)
# SHA-512 Hash Output(Hexadecimal): c24e291153fdff0a32316fc33c672ab5ae54a30d8b7c81e53b59932020a53deb4e7fe55eb5e060e700677afbcaae21a25f9d2ffde2ebb70842ae45279f4aa8c9
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 61002
# Structural Similarity Index 0.9999356815810477
# Processed: Covid (415).png → datasets/ctscan/RONI Watermarked/COVID/Covid (415).png
# Upper-left seed: (64, 6)
# Lower-left seed: (192, 11)
# Upper-right seed: (64, 308)
# Lower-right seed: (192, 314)
# SHA-512 Hash Output(Hexadecimal): c1ff9a4dea45b1b2b3f3918d0a9645c86507a387e25049062f45cebc43a92af8f8289b5278edca58bf0d76756a598ac18b231b2c670b881637b9df7c6eb5f563
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 37612
# Structural Similarity Index 0.9999764959702437
# Processed: Covid (100).png → datasets/ctscan/RONI Watermarked/COVID/Covid (100).png
# Upper-left seed: (52, 32)
# Lower-left seed: (156, 25)
# Upper-right seed: (52, 244)
# Lower-right seed: (156, 252)
# SHA-512 Hash Output(Hexadecimal): e77697bc17f96e85111af96a574380bf19573b23c227a07859455c3eed2634005a45240a2ad7f322cd74a0448e6b1e29750de3c123b6dbf88257b9fe31ca99a4
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 44641
# Structural Similarity Index 0.9998992347974451
# Processed: Covid (550).png → datasets/ctscan/RONI Watermarked/COVID/Covid (550).png
# Upper-left seed: (67, 15)
# Lower-left seed: (202, 21)
# Upper-right seed: (67, 307)
# Lower-right seed: (202, 299)
# SHA-512 Hash Output(Hexadecimal): 3a41d88f748e51a2e1fb684954a81a1bfeca7ab59b66ec6dec9ff4b5d938a13c37be9921b36ea2769eaa895d59a3f3184359a6ea3a85bba6db0434776468a4d7
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 44936
# Structural Similarity Index 0.9999724773478401
# Processed: Covid (47).png → datasets/ctscan/RONI Watermarked/COVID/Covid (47).png
# Upper-left seed: (62, 30)
# Lower-left seed: (186, 23)
# Upper-right seed: (62, 292)
# Lower-right seed: (186, 306)
# SHA-512 Hash Output(Hexadecimal): 03e642badc0d9001acba64a5ac007296475427870dd3ed8940d2149c45664a694b48cd55246f873b8e133679b81cb45d41e84bb7a19a0728e316dc45da97678a
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 48184
# Structural Similarity Index 0.9999635766839206
# Processed: Covid (803).png → datasets/ctscan/RONI Watermarked/COVID/Covid (803).png
# Upper-left seed: (47, 21)
# Lower-left seed: (143, 14)
# Upper-right seed: (47, 225)
# Lower-right seed: (143, 230)
# SHA-512 Hash Output(Hexadecimal): beecac71844bff528f12aa0d4fb85e05b0b34202ba72f914b74290fb864697c9fc5ea8e115b58be52e19df2eb6b5afba1d8f2efd88ed4e0f686087011525ffd8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 21944
# Structural Similarity Index 0.9999596453144649
# Processed: Covid (395).png → datasets/ctscan/RONI Watermarked/COVID/Covid (395).png
# Upper-left seed: (34, 68)
# Lower-left seed: (104, 52)
# Upper-right seed: (34, 183)
# Lower-right seed: (104, 196)
# SHA-512 Hash Output(Hexadecimal): c8c87c3ce83a8a23a493ddc7d1f9946d5d01731cd056d7f0128deb8dd7784a636b2df2d7f4b2aa195feadfec05799e815223f88d394103024b883b9b67ac3657
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 22831
# Structural Similarity Index 0.9998028303105356
# Processed: Covid (680).png → datasets/ctscan/RONI Watermarked/COVID/Covid (680).png
# Upper-left seed: (64, 15)
# Lower-left seed: (192, 18)
# Upper-right seed: (64, 335)
# Lower-right seed: (192, 330)
# SHA-512 Hash Output(Hexadecimal): a7984e1a1113d4afd6a883e33f3c424e647be024b824706f9b6be52141f177ce02c662a8b58fae22d1b1ea4588e1d4b38c353ce50d060f19a72b2580a3baf480
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 44375
# Structural Similarity Index 0.9999192520707827
# Processed: Covid (1211).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1211).png
# Upper-left seed: (61, 23)
# Lower-left seed: (185, 25)
# Upper-right seed: (61, 332)
# Lower-right seed: (185, 322)
# SHA-512 Hash Output(Hexadecimal): ccef93220be430f954637daefeb39bd4c83e0fdd83d01337193938a28b11670b07aaf6a0c44fd76ce67b5777881195c8c966f26377308c5684f7adc04e3d772b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 46694
# Structural Similarity Index 0.9999325501957765
# Processed: Covid (1138).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1138).png
# Upper-left seed: (54, 16)
# Lower-left seed: (164, 8)
# Upper-right seed: (54, 247)
# Lower-right seed: (164, 249)
# SHA-512 Hash Output(Hexadecimal): 0357f3d8c6cf344e7d3d40ef51a150ea36f2c204cc64607ff5859c97c3546c29e9ef5d6289bc69c003d6302dd576da1ecdf7941219b38725c39a57a65b1af56f
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 26546
# Structural Similarity Index 0.99996626724388
# Processed: Covid (403).png → datasets/ctscan/RONI Watermarked/COVID/Covid (403).png
# Upper-left seed: (58, 30)
# Lower-left seed: (176, 14)
# Upper-right seed: (58, 295)
# Lower-right seed: (176, 302)
# SHA-512 Hash Output(Hexadecimal): e2fd3c167f7fbf2df024903b563a9df4e2697d9c85a4497efd186a12d9041f858dde1aa157c6cadc30d13f45c72e4277218795999a972c35c4a7dd94aa2f38d6
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 31282
# Structural Similarity Index 0.9999213567097713
# Processed: Covid (1092).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1092).png
# Upper-left seed: (73, 11)
# Lower-left seed: (221, 13)
# Upper-right seed: (73, 331)
# Lower-right seed: (221, 322)
# SHA-512 Hash Output(Hexadecimal): 1c1f58bf69924caf05bc998d6e1619c22d03acaea44c67bed5b36dcdc85f63b3104c8c392433ab083162eb4d701ae3564cea8ba3aea7ca6dcd1a281254667588
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 53546
# Structural Similarity Index 0.9999680640441888
# Processed: Covid (950).png → datasets/ctscan/RONI Watermarked/COVID/Covid (950).png
# Upper-left seed: (58, 30)
# Lower-left seed: (174, 30)
# Upper-right seed: (58, 288)
# Lower-right seed: (174, 291)
# SHA-512 Hash Output(Hexadecimal): eec6aef860bcc2e900b16a5fecd47051f56381c550f289e771fb35c925a41e9123e6c70c421689d5544a3bd74d060d40f2e4d9cb61224bee68afdb81fba8aeae
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 40452
# Structural Similarity Index 0.9999634611147932
# Processed: Covid (815).png → datasets/ctscan/RONI Watermarked/COVID/Covid (815).png
# Upper-left seed: (64, 21)
# Lower-left seed: (194, 16)
# Upper-right seed: (64, 314)
# Lower-right seed: (194, 311)
# SHA-512 Hash Output(Hexadecimal): 5faa4a85b69bda15411f5ef57893f3dad34a35d33e5983009212135ac0b1125fd3a2d104ac09f8a128150908ee5f8ef4a7387dbef96ee8b8b03149c1ba389076
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 41927
# Structural Similarity Index 0.9999777725407268
# Processed: Covid (51).png → datasets/ctscan/RONI Watermarked/COVID/Covid (51).png
# Upper-left seed: (52, 30)
# Lower-left seed: (158, 28)
# Upper-right seed: (52, 249)
# Lower-right seed: (158, 250)
# SHA-512 Hash Output(Hexadecimal): 4f8f379122abcfeb9c749f59bf3ed8c250d080aea3c19a740b3d74498559b7c6ed5afe942556c48de03b2da8c73be831e1ad306752b03a2f9d6b5396eccb7500
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 46366
# Structural Similarity Index 0.9998980410850667
# Processed: Covid (546).png → datasets/ctscan/RONI Watermarked/COVID/Covid (546).png
# Upper-left seed: (78, 15)
# Lower-left seed: (236, 25)
# Upper-right seed: (78, 362)
# Lower-right seed: (236, 357)
# SHA-512 Hash Output(Hexadecimal): 3eb2bbb73e054dcf932f3e67572ede11862695cde6928ef196caa5ee7ae13448ff6b61c998ace22926233d38354d9762e77d6792e805aa571d85f98488495d76
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 60410
# Structural Similarity Index 0.9999832008878076
# Processed: Covid (116).png → datasets/ctscan/RONI Watermarked/COVID/Covid (116).png
# Upper-left seed: (37, 50)
# Lower-left seed: (113, 39)
# Upper-right seed: (37, 199)
# Lower-right seed: (113, 205)
# SHA-512 Hash Output(Hexadecimal): 9c7842edaaeb8bd63524ece636f7b8218618073987c9c81d970c6d18db971c5f8273b93517026cd09b4dbec3537c8357ddd0300779c86fde9412a6d51ab6e1a8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 22486
# Structural Similarity Index 0.9998676376235186
# Processed: Covid (638).png → datasets/ctscan/RONI Watermarked/COVID/Covid (638).png
# Upper-left seed: (48, 25)
# Lower-left seed: (145, 14)
# Upper-right seed: (48, 244)
# Lower-right seed: (145, 241)
# SHA-512 Hash Output(Hexadecimal): 3c2abf369347ebcc13672540df4046b74d0755dcbe7b025e28136059aa4b9b8a068050fec206b0a1489b36713b656bd7731b6e6ea7df0e175ca16839830f375b
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 25947
# Structural Similarity Index 0.9999573055288481
# Processed: Covid (268).png → datasets/ctscan/RONI Watermarked/COVID/Covid (268).png
# Upper-left seed: (59, 39)
# Lower-left seed: (179, 43)
# Upper-right seed: (59, 302)
# Lower-right seed: (179, 270)
# SHA-512 Hash Output(Hexadecimal): 10c2e0d0617cb622ef9b0db9bcb7b4afe6465e4b4ab2def10fd16bd1bc0959c62aaec68b39947051d666f3e37b1abf5598d0786f0b0850bafb67cfb59357d792
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 50898
# Structural Similarity Index 0.9999556916758015
# Processed: Covid (792).png → datasets/ctscan/RONI Watermarked/COVID/Covid (792).png
# Upper-left seed: (61, 37)
# Lower-left seed: (185, 26)
# Upper-right seed: (61, 274)
# Lower-right seed: (185, 275)
# SHA-512 Hash Output(Hexadecimal): f13106c9a950a8df543ec12b3f5b038e0d3e88dbf60e7ace77b69838c12b8001660d35fd8d69114535d6d28fef3241d79708d0087d051042b4f9591b86383ec4
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 52292
# Structural Similarity Index 0.9999555068069745
# Processed: Covid (287).png → datasets/ctscan/RONI Watermarked/COVID/Covid (287).png
# Upper-left seed: (81, 39)
# Lower-left seed: (244, 9)
# Upper-right seed: (81, 330)
# Lower-right seed: (244, 331)
# SHA-512 Hash Output(Hexadecimal): 9935986955cb6328a33f0d0599e49053dd7224de38e4c2f754fc0ec88abb9ab8db8ef05813589f8e5318955ac5c4fd662f085de0bd2df6551fafe1d76f5ed1f4
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 66139
# Structural Similarity Index 0.9999281779942243
# Processed: Covid (1246).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1246).png
# Upper-left seed: (72, 1)
# Lower-left seed: (217, 13)
# Upper-right seed: (72, 409)
# Lower-right seed: (217, 385)
# SHA-512 Hash Output(Hexadecimal): 7a65c7c6c9afeb0d70cb1121035a46103e02678044fd41f430d86e16c75cd10007841bdbeab9351438932a0ef0986bd495fdec5c6238df37f8888db775044b7d
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 105088
# Structural Similarity Index 0.9999717842625472
# Processed: Covid (907).png → datasets/ctscan/RONI Watermarked/COVID/Covid (907).png
# Upper-left seed: (67, 50)
# Lower-left seed: (201, 20)
# Upper-right seed: (67, 291)
# Lower-right seed: (201, 311)
# SHA-512 Hash Output(Hexadecimal): f47e2befa46f28fed1393245db55f67e1af458f7c5836d7e1f7c50ea2c7cffa5449f5b584511d857541fc558398ec8bb7a53ea7e39a112d1e5f3e0f1284569f8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 64361
# Structural Similarity Index 0.9999362827428883
# Processed: Covid (454).png → datasets/ctscan/RONI Watermarked/COVID/Covid (454).png
# Upper-left seed: (56, 19)
# Lower-left seed: (168, 12)
# Upper-right seed: (56, 270)
# Lower-right seed: (168, 262)
# SHA-512 Hash Output(Hexadecimal): ea1eb828c0447fd68e9ad90c43d2e46ef7a03b7d469eee58ce8de7e7046818ac512620eff73491899886bb58a8dba5d6ecd9d3d6bbeea5c714f1d21c97c8c7b4
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 42046
# Structural Similarity Index 0.9999849036902463
# Processed: Covid (141).png → datasets/ctscan/RONI Watermarked/COVID/Covid (141).png
# Upper-left seed: (63, 16)
# Lower-left seed: (191, 30)
# Upper-right seed: (63, 320)
# Lower-right seed: (191, 296)
# SHA-512 Hash Output(Hexadecimal): ccd435a3dd6e5a861971c098f034113e1cebbd790157d1a6c6f0eeefcb263d8b331700871dc20bdb6cb74539613f5f2aa21afcee90eef4095c7a025d18f74cd1
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 48813
# Structural Similarity Index 0.9999297180213457
# Processed: Covid (1180).png → datasets/ctscan/RONI Watermarked/COVID/Covid (1180).png
# Upper-left seed: (67, 34)
# Lower-left seed: (201, 34)
# Upper-right seed: (67, 319)
# Lower-right seed: (201, 317)
# SHA-512 Hash Output(Hexadecimal): b5feb607f8da24f03728bbc25b269cd7a95045b66463de04b096476bad88c39e571eb72e64b37cf7fe699a3d1c8a23d6892700b9a77bc574e9ccf1059264caf8
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 64153
# Structural Similarity Index 0.9999398584585395
# Processed: Covid (511).png → datasets/ctscan/RONI Watermarked/COVID/Covid (511).png
# Upper-left seed: (73, 22)
# Lower-left seed: (221, 24)
# Upper-right seed: (73, 334)
# Lower-right seed: (221, 331)
# SHA-512 Hash Output(Hexadecimal): f08ca794f410dcc4072f45680b24571a4b301d639b65ad72529432eed481794f22ae9241ebc94fb595a6878fc14e7533da07072e4098e5f5a82630a6fe206ac3
# Binary Representation of SHA-512 Hash: ...
# The length of the binary representation is: 1024
# Number of RONI pixels: 56341
# Structural Similarity Index 0.9999730267652481
# Processed: Covid (842).png → datasets/ctscan/RONI Watermarked/COVID/Covid (842).png
